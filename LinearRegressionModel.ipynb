# %%
import numpy as np
import torch 
import pandas as pd
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn.functional as F

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1,1)
        
    def forward(self,x):
        return self.linear(x)
    
model = LinearRegressionModel()

# %%
class CustomDataset(Dataset):
    def __init__(self, csv_path):
        df = pd.read_csv(csv_path)
        self.x_data = df.iloc[:,:1].values
        self.y_data = df.iloc[:,1:].values

    def __len__(self):
        return len(self.x_data) 

    def __getitem__(self,idx):
        inp = torch.FloatTensor(self.x_data[idx])
        outp = torch.FloatTensor(self.y_data[idx])
        return inp, outp # 해당하는 idx(인덱스)의 input과 output 데이터를 반환한다.

# %%
path = 'file_path'
Epochs = 100

dataset = CustomDataset(path)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

for epoch in range(Epochs + 1):
    for batch_idx, samples in enumerate(dataloader):
        x_train, y_train = samples

    prediction = model(x_train)
    cost = F.mse_loss(prediction,y_train)

    optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()


    print('Epoch {:4d}/{} ## hypothesis: {} ## Cost: {:.6f}'.format(epoch, Epochs, prediction.squeeze().detach(),cost.item()))

print(list(model.parameters()))
# Out:
# Epoch    0/300 ## hypothesis: tensor([1.8218, 0.2258]) ## Cost: 2564.647949
# Epoch    1/300 ## hypothesis: tensor([3.9582, 5.2519]) ## Cost: 2877.418945
# Epoch    2/300 ## hypothesis: tensor([ 1.5036, 11.9968]) ## Cost: 2783.503418
# Epoch    3/300 ## hypothesis: tensor([10.8283, 10.4104]) ## Cost: 1693.805176
# Epoch    4/300 ## hypothesis: tensor([18.6360, 10.8324]) ## Cost: 1971.776001
# Epoch    5/300 ## hypothesis: tensor([ 3.7396, 11.0916]) ## Cost: 513.935181
# Epoch    6/300 ## hypothesis: tensor([25.5874, 28.4573]) ## Cost: 3557.875000
# Epoch    7/300 ## hypothesis: tensor([ 4.8086, 10.2791]) ## Cost: 86.434647
# Epoch    8/300 ## hypothesis: tensor([20.5573, 19.7084]) ## Cost: 743.660889
# Epoch    9/300 ## hypothesis: tensor([ 3.8152, 15.5314]) ## Cost: 142.800873
# Epoch   10/300 ## hypothesis: tensor([30.8017,  9.3463]) ## Cost: 784.721436
# Epoch   11/300 ## hypothesis: tensor([22.0532, 23.0225]) ## Cost: 609.965027
# Epoch   12/300 ## hypothesis: tensor([13.4725, 25.6606]) ## Cost: 276.522736
# Epoch   13/300 ## hypothesis: tensor([ 3.9323, 13.3174]) ## Cost: 101.808601
# Epoch   14/300 ## hypothesis: tensor([30.2245,  3.4379]) ## Cost: 497.140076
# Epoch   15/300 ## hypothesis: tensor([17.1554, 11.1763]) ## Cost: 193.596237
# Epoch   16/300 ## hypothesis: tensor([10.2325, 49.3593]) ## Cost: 1095.976685
# Epoch   17/300 ## hypothesis: tensor([47.2907, 24.1207]) ## Cost: 655.847900
# Epoch   18/300 ## hypothesis: tensor([ 4.7762, 45.5088]) ## Cost: 380.589172
# Epoch   19/300 ## hypothesis: tensor([17.8766, 61.2190]) ## Cost: 646.256348
# Epoch   20/300 ## hypothesis: tensor([-0.2363, 11.3655]) ## Cost: 1.935243
# Epoch   21/300 ## hypothesis: tensor([66.6762, 25.7094]) ## Cost: 660.737061
# Epoch   22/300 ## hypothesis: tensor([24.2766, 48.7891]) ## Cost: 186.558350
# Epoch   23/300 ## hypothesis: tensor([15.2070, 71.8296]) ## Cost: 242.870819
# Epoch   24/300 ## hypothesis: tensor([49.7439, 19.4535]) ## Cost: 104.000595
# Epoch   25/300 ## hypothesis: tensor([49.6518,  6.6724]) ## Cost: 39.072666
# Epoch   26/300 ## hypothesis: tensor([26.0480, 19.0907]) ## Cost: 69.292023
# Epoch   27/300 ## hypothesis: tensor([63.5577,  9.8786]) ## Cost: 269.915344
# Epoch   28/300 ## hypothesis: tensor([22.8775, 18.8927]) ## Cost: 36.359013
# Epoch   29/300 ## hypothesis: tensor([62.1532, 75.7506]) ## Cost: 365.039917
# Epoch   30/300 ## hypothesis: tensor([68.0491, 66.3837]) ## Cost: 214.840759
# Epoch   31/300 ## hypothesis: tensor([49.3664, 27.1318]) ## Cost: 96.449448
# Epoch   32/300 ## hypothesis: tensor([17.9157, 29.1510]) ## Cost: 39.391243
# Epoch   33/300 ## hypothesis: tensor([ 0.6343, 40.5532]) ## Cost: 90.125282
# Epoch   34/300 ## hypothesis: tensor([82.7936, 81.0457]) ## Cost: 103.326523
# Epoch   35/300 ## hypothesis: tensor([ 6.9104, 66.7373]) ## Cost: 48.563168
# Epoch   36/300 ## hypothesis: tensor([43.8248, 37.5308]) ## Cost: 3.670952
# Epoch   37/300 ## hypothesis: tensor([65.5238, 18.6833]) ## Cost: 33.962856
# Epoch   38/300 ## hypothesis: tensor([81.3884, 42.3916]) ## Cost: 117.834908
# Epoch   39/300 ## hypothesis: tensor([21.9069, 23.7519]) ## Cost: 3.809384
# Epoch   40/300 ## hypothesis: tensor([74.5599, 53.3225]) ## Cost: 19.993576
# Epoch   41/300 ## hypothesis: tensor([20.2076, 82.4574]) ## Cost: 42.357807
# Epoch   42/300 ## hypothesis: tensor([ 6.3216, 26.9206]) ## Cost: 2.791289
# Epoch   43/300 ## hypothesis: tensor([21.3040, 44.7132]) ## Cost: 2.789512
# Epoch   44/300 ## hypothesis: tensor([19.4535, 46.6391]) ## Cost: 21.027023
# Epoch   45/300 ## hypothesis: tensor([61.8216, 32.6750]) ## Cost: 49.575409
# Epoch   46/300 ## hypothesis: tensor([20.6054, -0.2324]) ## Cost: 8.261658
# Epoch   47/300 ## hypothesis: tensor([33.8977, 91.7292]) ## Cost: 11.399208
# Epoch   48/300 ## hypothesis: tensor([73.1177, 95.0275]) ## Cost: 17.177977
# Epoch   49/300 ## hypothesis: tensor([43.9261, 44.8861]) ## Cost: 12.569111
# Epoch   50/300 ## hypothesis: tensor([24.8124, 30.5919]) ## Cost: 6.412778
# Epoch   51/300 ## hypothesis: tensor([81.6479, 90.3175]) ## Cost: 15.487409
# Epoch   52/300 ## hypothesis: tensor([73.4362, 76.3442]) ## Cost: 2.876107
# Epoch   53/300 ## hypothesis: tensor([39.5900, 15.3083]) ## Cost: 13.920458
# Epoch   54/300 ## hypothesis: tensor([42.5134,  5.5969]) ## Cost: 1.188320
# Epoch   55/300 ## hypothesis: tensor([49.3475, 51.2918]) ## Cost: 3.821369
# Epoch   56/300 ## hypothesis: tensor([76.4135, 89.9963]) ## Cost: 2.721241
# Epoch   57/300 ## hypothesis: tensor([96.9129, 46.3976]) ## Cost: 6.162293
# Epoch   58/300 ## hypothesis: tensor([66.0912, 69.0172]) ## Cost: 12.970516
# Epoch   59/300 ## hypothesis: tensor([81.4967, 73.7130]) ## Cost: 8.077223
# Epoch   60/300 ## hypothesis: tensor([18.3384, 23.2253]) ## Cost: 1.669919
# Epoch   61/300 ## hypothesis: tensor([86.7072, 88.6609]) ## Cost: 13.431919
# Epoch   62/300 ## hypothesis: tensor([96.1182, 45.9768]) ## Cost: 14.125783
# Epoch   63/300 ## hypothesis: tensor([70.8464, 59.9872]) ## Cost: 10.969336
# Epoch   64/300 ## hypothesis: tensor([57.8558, 24.3815]) ## Cost: 39.305435
# Epoch   65/300 ## hypothesis: tensor([39.3202, 93.7040]) ## Cost: 32.679131
# Epoch   66/300 ## hypothesis: tensor([19.7098, 85.5168]) ## Cost: 2.500993
# Epoch   67/300 ## hypothesis: tensor([13.7002, 14.6953]) ## Cost: 8.044731
# Epoch   68/300 ## hypothesis: tensor([20.6649, 64.4484]) ## Cost: 11.045311
# Epoch   69/300 ## hypothesis: tensor([26.5519, 20.6000]) ## Cost: 9.758434
# Epoch   70/300 ## hypothesis: tensor([60.2694, 80.1059]) ## Cost: 19.969681
# Epoch   71/300 ## hypothesis: tensor([83.2289, 58.3895]) ## Cost: 0.020101
# Epoch   72/300 ## hypothesis: tensor([12.6850, 20.6338]) ## Cost: 6.655733
# Epoch   73/300 ## hypothesis: tensor([48.4544, 43.4864]) ## Cost: 4.735285
# Epoch   74/300 ## hypothesis: tensor([76.4309, 47.5580]) ## Cost: 0.730315
# Epoch   75/300 ## hypothesis: tensor([ 8.7343, 75.4815]) ## Cost: 3.843359
# Epoch   76/300 ## hypothesis: tensor([20.6613, 28.6205]) ## Cost: 15.335930
# Epoch   77/300 ## hypothesis: tensor([48.4367, 61.3487]) ## Cost: 19.718761
# Epoch   78/300 ## hypothesis: tensor([38.6898, 25.7160]) ## Cost: 0.807910
# Epoch   79/300 ## hypothesis: tensor([94.6317, 94.6317]) ## Cost: 0.602608
# Epoch   80/300 ## hypothesis: tensor([86.5168, 59.5949]) ## Cost: 21.099863
# Epoch   81/300 ## hypothesis: tensor([20.6806,  4.7474]) ## Cost: 37.272022
# Epoch   82/300 ## hypothesis: tensor([60.6270, 57.6339]) ## Cost: 0.357067
# Epoch   83/300 ## hypothesis: tensor([53.6048,  0.7654]) ## Cost: 6.012453
# Epoch   84/300 ## hypothesis: tensor([14.7373, 90.5798]) ## Cost: 15.823093
# Epoch   85/300 ## hypothesis: tensor([33.5415, 47.4481]) ## Cost: 4.741489
# Epoch   86/300 ## hypothesis: tensor([34.5647, 73.3376]) ## Cost: 1.578882
# Epoch   87/300 ## hypothesis: tensor([ 3.7393, 25.5793]) ## Cost: 17.999899
# Epoch   88/300 ## hypothesis: tensor([53.4002, 55.3865]) ## Cost: 9.439046
# Epoch   89/300 ## hypothesis: tensor([51.3250, 26.5382]) ## Cost: 0.082079
# Epoch   90/300 ## hypothesis: tensor([70.1797, 52.3290]) ## Cost: 2.895924
# Epoch   91/300 ## hypothesis: tensor([11.6548, 48.3046]) ## Cost: 4.363238
# Epoch   92/300 ## hypothesis: tensor([18.6003, 73.1134]) ## Cost: 8.377859
# Epoch   93/300 ## hypothesis: tensor([21.5497, 36.4005]) ## Cost: 18.266373
# Epoch   94/300 ## hypothesis: tensor([69.2536, 33.5184]) ## Cost: 5.746264
# Epoch   95/300 ## hypothesis: tensor([91.3015, 69.4132]) ## Cost: 18.568218
# Epoch   96/300 ## hypothesis: tensor([94.1950, 48.4728]) ## Cost: 10.198637
# Epoch   97/300 ## hypothesis: tensor([95.1928, 29.5887]) ## Cost: 30.186836
# Epoch   98/300 ## hypothesis: tensor([79.7989, 98.5714]) ## Cost: 10.209006
# Epoch   99/300 ## hypothesis: tensor([48.4446, 55.3983]) ## Cost: 4.539604
# Epoch  100/300 ## hypothesis: tensor([69.2426, 40.4605]) ## Cost: 7.663526
# Epoch  101/300 ## hypothesis: tensor([36.5918, 83.3671]) ## Cost: 1.986902
# Epoch  102/300 ## hypothesis: tensor([70.5573, 10.7359]) ## Cost: 2.255147
# Epoch  103/300 ## hypothesis: tensor([64.4760, 58.5030]) ## Cost: 8.287421
# Epoch  104/300 ## hypothesis: tensor([80.6793, 50.7124]) ## Cost: 23.208771
# Epoch  105/300 ## hypothesis: tensor([84.2073, 27.9150]) ## Cost: 2.296671
# Epoch  106/300 ## hypothesis: tensor([90.2953, 58.1081]) ## Cost: 7.426465
# Epoch  107/300 ## hypothesis: tensor([ 2.7920, 32.0161]) ## Cost: 7.135194
# Epoch  108/300 ## hypothesis: tensor([88.3444, 84.3182]) ## Cost: 2.829095
# Epoch  109/300 ## hypothesis: tensor([50.1601, 11.8627]) ## Cost: 13.773599
# Epoch  110/300 ## hypothesis: tensor([70.2940,  3.7989]) ## Cost: 17.062929
# Epoch  111/300 ## hypothesis: tensor([50.2542, 13.9047]) ## Cost: 18.488596
# Epoch  112/300 ## hypothesis: tensor([46.1332, 22.9510]) ## Cost: 2.492807
# Epoch  113/300 ## hypothesis: tensor([38.0332, 25.9497]) ## Cost: 0.703465
# Epoch  114/300 ## hypothesis: tensor([18.9010, 89.3881]) ## Cost: 7.082400
# Epoch  115/300 ## hypothesis: tensor([44.1131, 89.4652]) ## Cost: 7.598456
# Epoch  116/300 ## hypothesis: tensor([53.9888, 90.1355]) ## Cost: 2.037144
# Epoch  117/300 ## hypothesis: tensor([59.0104, 23.8670]) ## Cost: 12.307457
# Epoch  118/300 ## hypothesis: tensor([ 4.7904, 41.9508]) ## Cost: 9.209783
# Epoch  119/300 ## hypothesis: tensor([68.0874, 68.0874]) ## Cost: 5.031204
# Epoch  120/300 ## hypothesis: tensor([87.4120, 96.4785]) ## Cost: 5.127668
# Epoch  121/300 ## hypothesis: tensor([14.8361, 95.1955]) ## Cost: 16.445913
# Epoch  122/300 ## hypothesis: tensor([86.9661, 87.9684]) ## Cost: 3.796885
# Epoch  123/300 ## hypothesis: tensor([93.7642, 97.7640]) ## Cost: 16.307159
# Epoch  124/300 ## hypothesis: tensor([91.0936, 75.2109]) ## Cost: 2.755133
# Epoch  125/300 ## hypothesis: tensor([ 7.6875, 76.9793]) ## Cost: 40.367733
# Epoch  126/300 ## hypothesis: tensor([98.2516, 24.6380]) ## Cost: 39.168022
# Epoch  127/300 ## hypothesis: tensor([35.2556, 34.2699]) ## Cost: 1.554625
# Epoch  128/300 ## hypothesis: tensor([51.9970, 60.8660]) ## Cost: 10.392239
# Epoch  129/300 ## hypothesis: tensor([46.2309,  4.7113]) ## Cost: 7.895661
# Epoch  130/300 ## hypothesis: tensor([72.0075, 98.7260]) ## Cost: 52.597836
# Epoch  131/300 ## hypothesis: tensor([41.8030, 44.8055]) ## Cost: 1.055173
# Epoch  132/300 ## hypothesis: tensor([26.8008, 77.8616]) ## Cost: 26.283409
# Epoch  133/300 ## hypothesis: tensor([95.3702, 85.3068]) ## Cost: 6.849306
# Epoch  134/300 ## hypothesis: tensor([33.8933,  2.7797]) ## Cost: 2.894021
# Epoch  135/300 ## hypothesis: tensor([23.8756, 76.1070]) ## Cost: 11.101431
# Epoch  136/300 ## hypothesis: tensor([61.2632,  1.7850]) ## Cost: 1.824951
# Epoch  137/300 ## hypothesis: tensor([87.4643, 96.5363]) ## Cost: 37.100216
# Epoch  138/300 ## hypothesis: tensor([64.6808, 91.6443]) ## Cost: 3.181531
# Epoch  139/300 ## hypothesis: tensor([92.5086, 41.6512]) ## Cost: 6.900805
# Epoch  140/300 ## hypothesis: tensor([33.6055, 59.4808]) ## Cost: 4.045162
# Epoch  141/300 ## hypothesis: tensor([24.6598, 44.5727]) ## Cost: 1.315977
# Epoch  142/300 ## hypothesis: tensor([49.5912, 97.4208]) ## Cost: 0.712831
# Epoch  143/300 ## hypothesis: tensor([85.5665, 50.6488]) ## Cost: 15.906960
# Epoch  144/300 ## hypothesis: tensor([18.8305, 11.8078]) ## Cost: 0.615989
# Epoch  145/300 ## hypothesis: tensor([ 0.7718, 52.9303]) ## Cost: 13.262556
# Epoch  146/300 ## hypothesis: tensor([79.1870, 86.2241]) ## Cost: 2.219959
# Epoch  147/300 ## hypothesis: tensor([ 4.8057, 72.2995]) ## Cost: 5.535828
# Epoch  148/300 ## hypothesis: tensor([94.3797, 39.0223]) ## Cost: 1.079657
# Epoch  149/300 ## hypothesis: tensor([50.1682, 46.1362]) ## Cost: 10.444325
# Epoch  150/300 ## hypothesis: tensor([56.1429, 29.9692]) ## Cost: 2.032942
# Epoch  151/300 ## hypothesis: tensor([61.1321, 59.1202]) ## Cost: 4.533797
# Epoch  152/300 ## hypothesis: tensor([74.3034, 21.9277]) ## Cost: 13.414574
# Epoch  153/300 ## hypothesis: tensor([ 6.7988, 95.1772]) ## Cost: 6.806721
# Epoch  154/300 ## hypothesis: tensor([97.3968, 84.3126]) ## Cost: 5.131851
# Epoch  155/300 ## hypothesis: tensor([96.0365, 44.8942]) ## Cost: 0.785501
# Epoch  156/300 ## hypothesis: tensor([66.9599, 21.8315]) ## Cost: 2.156503
# Epoch  157/300 ## hypothesis: tensor([33.8160, 36.8201]) ## Cost: 15.795912
# Epoch  158/300 ## hypothesis: tensor([24.8711, 30.8956]) ## Cost: 15.827490
# Epoch  159/300 ## hypothesis: tensor([73.9557, 13.8041]) ## Cost: 18.585327
# Epoch  160/300 ## hypothesis: tensor([12.7693, 67.7721]) ## Cost: 0.815055
# Epoch  161/300 ## hypothesis: tensor([77.8389, 41.8065]) ## Cost: 11.047997
# Epoch  162/300 ## hypothesis: tensor([93.2043, 51.0076]) ## Cost: 6.661078
# Epoch  163/300 ## hypothesis: tensor([87.1250, 73.0676]) ## Cost: 1.561088
# Epoch  164/300 ## hypothesis: tensor([64.9606, 86.0227]) ## Cost: 3.936528
# Epoch  165/300 ## hypothesis: tensor([80.8788, 59.8503]) ## Cost: 1.549654
# Epoch  166/300 ## hypothesis: tensor([99.9402, 11.7892]) ## Cost: 12.415034
# Epoch  167/300 ## hypothesis: tensor([41.8174, 76.8581]) ## Cost: 4.523777
# Epoch  168/300 ## hypothesis: tensor([53.6889, 53.6889]) ## Cost: 1.743491
# Epoch  169/300 ## hypothesis: tensor([66.6959, 31.7338]) ## Cost: 17.582228
# Epoch  170/300 ## hypothesis: tensor([78.0129,  8.7968]) ## Cost: 5.266952
# Epoch  171/300 ## hypothesis: tensor([20.8581, 98.1860]) ## Cost: 4.611432
# Epoch  172/300 ## hypothesis: tensor([44.0200,  0.7744]) ## Cost: 3.111670
# Epoch  173/300 ## hypothesis: tensor([26.8937, 87.1715]) ## Cost: 16.309687
# Epoch  174/300 ## hypothesis: tensor([52.0230, 12.8322]) ## Cost: 10.160630
# Epoch  175/300 ## hypothesis: tensor([98.1745, 83.1124]) ## Cost: 5.463482
# Epoch  176/300 ## hypothesis: tensor([47.1277, 44.1048]) ## Cost: 2.498048
# Epoch  177/300 ## hypothesis: tensor([47.1954, 71.4133]) ## Cost: 0.622732
# Epoch  178/300 ## hypothesis: tensor([14.8947, 23.9704]) ## Cost: 19.394239
# Epoch  179/300 ## hypothesis: tensor([52.1959, 79.4177]) ## Cost: 8.062136
# Epoch  180/300 ## hypothesis: tensor([18.9185, 61.2497]) ## Cost: 7.078024
# Epoch  181/300 ## hypothesis: tensor([25.9781, 30.0103]) ## Cost: 1.990637
# Epoch  182/300 ## hypothesis: tensor([100.4955,  58.1902]) ## Cost: 41.419903
# Epoch  183/300 ## hypothesis: tensor([16.0521, 47.6011]) ## Cost: 3.063704
# Epoch  184/300 ## hypothesis: tensor([19.0856, 89.2364]) ## Cost: 10.350836
# Epoch  185/300 ## hypothesis: tensor([42.3688, 91.0545]) ## Cost: 41.155361
# Epoch  186/300 ## hypothesis: tensor([100.0735,  69.6781]) ## Cost: 24.994598
# Epoch  187/300 ## hypothesis: tensor([37.0488, 89.4426]) ## Cost: 10.999751
# Epoch  188/300 ## hypothesis: tensor([66.5029,  6.8466]) ## Cost: 4.261040
# Epoch  189/300 ## hypothesis: tensor([99.6877, 94.6412]) ## Cost: 1.010621
# Epoch  190/300 ## hypothesis: tensor([74.5971, 29.0933]) ## Cost: 5.291153
# Epoch  191/300 ## hypothesis: tensor([74.4064, 68.3547]) ## Cost: 7.095447
# Epoch  192/300 ## hypothesis: tensor([62.1787, 55.1324]) ## Cost: 17.231180
# Epoch  193/300 ## hypothesis: tensor([49.3311, 24.0442]) ## Cost: 8.143398
# Epoch  194/300 ## hypothesis: tensor([25.0796, 86.8380]) ## Cost: 4.765429
# Epoch  195/300 ## hypothesis: tensor([56.4209, 48.3278]) ## Cost: 13.718972
# Epoch  196/300 ## hypothesis: tensor([81.4572, 42.1257]) ## Cost: 18.420475
# Epoch  197/300 ## hypothesis: tensor([36.0572, 86.4581]) ## Cost: 0.685793
# Epoch  198/300 ## hypothesis: tensor([71.3885, 68.3623]) ## Cost: 13.735662
# Epoch  199/300 ## hypothesis: tensor([ 7.7974, 81.0598]) ## Cost: 2.400351
# Epoch  200/300 ## hypothesis: tensor([23.8125, 87.9296]) ## Cost: 12.146596
# Epoch  201/300 ## hypothesis: tensor([63.8413,  2.7719]) ## Cost: 16.725031
# Epoch  202/300 ## hypothesis: tensor([ 8.7941, 99.0495]) ## Cost: 16.802246
# Epoch  203/300 ## hypothesis: tensor([53.7237, 53.7237]) ## Cost: 11.038975
# Epoch  204/300 ## hypothesis: tensor([93.5473, 49.6508]) ## Cost: 2.573837
# Epoch  205/300 ## hypothesis: tensor([24.7670, 31.7666]) ## Cost: 0.024071
# Epoch  206/300 ## hypothesis: tensor([ 5.7686, 73.7700]) ## Cost: 2.253454
# Epoch  207/300 ## hypothesis: tensor([20.7360, 97.6167]) ## Cost: 2.112449
# Epoch  208/300 ## hypothesis: tensor([ 8.7659, 69.7482]) ## Cost: 12.636333
# Epoch  209/300 ## hypothesis: tensor([59.8929, 52.8784]) ## Cost: 11.022331
# Epoch  210/300 ## hypothesis: tensor([79.2058, 97.3054]) ## Cost: 5.081374
# Epoch  211/300 ## hypothesis: tensor([49.8740, 32.8382]) ## Cost: 2.951387
# Epoch  212/300 ## hypothesis: tensor([47.9280, 90.0674]) ## Cost: 11.186450
# Epoch  213/300 ## hypothesis: tensor([28.9874, 91.4551]) ## Cost: 0.243972
# Epoch  214/300 ## hypothesis: tensor([97.5635, 12.8752]) ## Cost: 16.124662
# Epoch  215/300 ## hypothesis: tensor([61.0305,  9.8116]) ## Cost: 5.157854
# Epoch  216/300 ## hypothesis: tensor([92.0884, 81.0502]) ## Cost: 13.066041
# Epoch  217/300 ## hypothesis: tensor([99.6234, 53.6902]) ## Cost: 13.744007
# Epoch  218/300 ## hypothesis: tensor([83.6890, 15.7534]) ## Cost: 3.212070
# Epoch  219/300 ## hypothesis: tensor([28.7776,  7.7710]) ## Cost: 0.678991
# Epoch  220/300 ## hypothesis: tensor([96.8226,  4.7713]) ## Cost: 1.667216
# Epoch  221/300 ## hypothesis: tensor([33.8424, 55.8901]) ## Cost: 3.792534
# Epoch  222/300 ## hypothesis: tensor([99.0781, 40.8968]) ## Cost: 0.436438
# Epoch  223/300 ## hypothesis: tensor([ 3.7851, 86.1235]) ## Cost: 20.388067
# Epoch  224/300 ## hypothesis: tensor([49.0856, 31.9757]) ## Cost: 0.538890
# Epoch  225/300 ## hypothesis: tensor([44.0555, 31.9773]) ## Cost: 7.446959
# Epoch  226/300 ## hypothesis: tensor([63.2806, 55.2156]) ## Cost: 7.716837
# Epoch  227/300 ## hypothesis: tensor([82.6316, 98.8000]) ## Cost: 14.986746
# Epoch  228/300 ## hypothesis: tensor([25.0298, 58.3744]) ## Cost: 5.182744
# Epoch  229/300 ## hypothesis: tensor([48.2038, 58.2944]) ## Cost: 6.668484
# Epoch  230/300 ## hypothesis: tensor([76.6125,  9.8798]) ## Cost: 12.502878
# Epoch  231/300 ## hypothesis: tensor([84.9462, 43.3715]) ## Cost: 1.756163
# Epoch  232/300 ## hypothesis: tensor([52.4080, 63.5432]) ## Cost: 1.260570
# Epoch  233/300 ## hypothesis: tensor([24.0348, 48.3010]) ## Cost: 0.788607
# Epoch  234/300 ## hypothesis: tensor([91.7275, 47.2639]) ## Cost: 0.065707
# Epoch  235/300 ## hypothesis: tensor([54.3577,  6.8451]) ## Cost: 17.524529
# Epoch  236/300 ## hypothesis: tensor([ 8.8380, 94.4932]) ## Cost: 23.643442
# Epoch  237/300 ## hypothesis: tensor([74.9098, 48.8608]) ## Cost: 9.636084
# Epoch  238/300 ## hypothesis: tensor([28.9038,  3.7873]) ## Cost: 1.861618
# Epoch  239/300 ## hypothesis: tensor([-0.2314, 15.8364]) ## Cost: 11.915781
# Epoch  240/300 ## hypothesis: tensor([51.9508, 91.0876]) ## Cost: 5.686481
# Epoch  241/300 ## hypothesis: tensor([23.9341, 51.1204]) ## Cost: 4.183610
# Epoch  242/300 ## hypothesis: tensor([81.3522,  8.8334]) ## Cost: 14.513231
# Epoch  243/300 ## hypothesis: tensor([67.0850, 71.1039]) ## Cost: 7.489588
# Epoch  244/300 ## hypothesis: tensor([54.1289, 23.9287]) ## Cost: 3.215189
# Epoch  245/300 ## hypothesis: tensor([ 5.8023, 18.8755]) ## Cost: 7.646873
# Epoch  246/300 ## hypothesis: tensor([45.0073, 38.9754]) ## Cost: 4.776662
# Epoch  247/300 ## hypothesis: tensor([16.8281, 21.8457]) ## Cost: 9.267914
# Epoch  248/300 ## hypothesis: tensor([77.1288, 87.1756]) ## Cost: 2.768319
# Epoch  249/300 ## hypothesis: tensor([55.8862, 35.8442]) ## Cost: 11.266153
# Epoch  250/300 ## hypothesis: tensor([59.7541, 69.7516]) ## Cost: 5.822818
# Epoch  251/300 ## hypothesis: tensor([42.7239, 30.7363]) ## Cost: 7.106950
# Epoch  252/300 ## hypothesis: tensor([57.8155, 74.8293]) ## Cost: 0.730826
# Epoch  253/300 ## hypothesis: tensor([28.7636, 49.7600]) ## Cost: 8.856959
# Epoch  254/300 ## hypothesis: tensor([60.6732, 39.7060]) ## Cost: 0.111703
# Epoch  255/300 ## hypothesis: tensor([29.7301, 53.6994]) ## Cost: 1.316520
# Epoch  256/300 ## hypothesis: tensor([ 5.7662, 37.7536]) ## Cost: 7.401394
# Epoch  257/300 ## hypothesis: tensor([24.7537, 97.7104]) ## Cost: 0.301036
# Epoch  258/300 ## hypothesis: tensor([37.7323, 85.6865]) ## Cost: 0.218489
# Epoch  259/300 ## hypothesis: tensor([41.7064, 60.6783]) ## Cost: 0.237458
# Epoch  260/300 ## hypothesis: tensor([89.6432, 52.6947]) ## Cost: 5.817831
# Epoch  261/300 ## hypothesis: tensor([25.6501,  9.7229]) ## Cost: 4.603333
# Epoch  262/300 ## hypothesis: tensor([74.4109, 54.5063]) ## Cost: 5.170969
# Epoch  263/300 ## hypothesis: tensor([57.4422, 47.4984]) ## Cost: 6.587896
# Epoch  264/300 ## hypothesis: tensor([22.5948, 49.3910]) ## Cost: 6.978487
# Epoch  265/300 ## hypothesis: tensor([85.9926, 75.0907]) ## Cost: 3.395605
# Epoch  266/300 ## hypothesis: tensor([15.6713, 99.1613]) ## Cost: 9.163643
# Epoch  267/300 ## hypothesis: tensor([59.6301, 14.7339]) ## Cost: 5.227303
# Epoch  268/300 ## hypothesis: tensor([ 6.7636, 24.7512]) ## Cost: 9.414226
# Epoch  269/300 ## hypothesis: tensor([43.6925, 92.6079]) ## Cost: 2.170897
# Epoch  270/300 ## hypothesis: tensor([32.7603, 52.7553]) ## Cost: 9.213443
# Epoch  271/300 ## hypothesis: tensor([57.9095,  7.7880]) ## Cost: 1.346365
# Epoch  272/300 ## hypothesis: tensor([56.8853, 43.8587]) ## Cost: 0.083985
# Epoch  273/300 ## hypothesis: tensor([49.8855, 94.9908]) ## Cost: 0.120817
# Epoch  274/300 ## hypothesis: tensor([99.0515, 36.8743]) ## Cost: 1.203238
# Epoch  275/300 ## hypothesis: tensor([75.0801, 32.9056]) ## Cost: 5.754180
# Epoch  276/300 ## hypothesis: tensor([89.9237,  4.7771]) ## Cost: 0.285185
# Epoch  277/300 ## hypothesis: tensor([76.8758,  3.7741]) ## Cost: 17.669304
# Epoch  278/300 ## hypothesis: tensor([48.8731, 36.8475]) ## Cost: 26.903053
# Epoch  279/300 ## hypothesis: tensor([47.0515, 51.0756]) ## Cost: 7.839052
# Epoch  280/300 ## hypothesis: tensor([19.8342, 49.9326]) ## Cost: 3.068152
# Epoch  281/300 ## hypothesis: tensor([41.8527, 77.9248]) ## Cost: 1.847384
# Epoch  282/300 ## hypothesis: tensor([49.9259, 24.8472]) ## Cost: 0.201769
# Epoch  283/300 ## hypothesis: tensor([84.0392, 84.0392]) ## Cost: 2.800917
# Epoch  284/300 ## hypothesis: tensor([24.8684, 54.9883]) ## Cost: 0.537172
# Epoch  285/300 ## hypothesis: tensor([39.9037, -0.2314]) ## Cost: 2.777908
# Epoch  286/300 ## hypothesis: tensor([85.0485, 54.9497]) ## Cost: 12.021115
# Epoch  287/300 ## hypothesis: tensor([42.9149, 73.0170]) ## Cost: 2.562615
# Epoch  288/300 ## hypothesis: tensor([65.0750, 76.1269]) ## Cost: 1.130854
# Epoch  289/300 ## hypothesis: tensor([97.2790,  7.8107]) ## Cost: 0.785500
# Epoch  290/300 ## hypothesis: tensor([75.1123, 15.8420]) ## Cost: 4.839675
# Epoch  291/300 ## hypothesis: tensor([92.9924, 31.8456]) ## Cost: 8.001233
# Epoch  292/300 ## hypothesis: tensor([15.8124, 57.9273]) ## Cost: 0.831871
# Epoch  293/300 ## hypothesis: tensor([41.8557, 86.9490]) ## Cost: 4.567563
# Epoch  294/300 ## hypothesis: tensor([89.2021, 25.8953]) ## Cost: 12.696465
# Epoch  295/300 ## hypothesis: tensor([ 4.7743, 28.8013]) ## Cost: 0.669407
# Epoch  296/300 ## hypothesis: tensor([29.7926, 15.7814]) ## Cost: 4.364083
# Epoch  297/300 ## hypothesis: tensor([75.8939, 76.8955]) ## Cost: 3.051048
# Epoch  298/300 ## hypothesis: tensor([ 2.7666, 89.7088]) ## Cost: 29.317909
# Epoch  299/300 ## hypothesis: tensor([87.1243, 43.9485]) ## Cost: 4.812884
# Epoch  300/300 ## hypothesis: tensor([41.0128, 95.3342]) ## Cost: 4.127554
# [Parameter containing:
# tensor([[1.0072]], requires_grad=True), Parameter containing:
# tensor([-0.2312], requires_grad=True)]
